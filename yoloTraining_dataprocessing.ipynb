# %%
# install dependencies
#!sudo apt-get install python python3-dev fftw3-dev libblas3 liblapack3 libarmadillo-dev

# cd to aitom directory
#%cd /Users/diwaker/Documents/TomekPaperTomo/aitom
# !pwd
# install other dependencies using pip
# !pip install -r requirements.txt
# !pip install opencv-contrib-python
# go back to /content dir
#%cd /Users/diwaker/Documents/TomekPaperTomo/
# Out:
# /Users/diwaker/Documents/INDIA/productDev/yolo_utils
# ...

# %% [raw]
# #### 2.1 installation (the first time)
# **NOTE**: you only need to run the following code once, instead of rebuilding every time. The cloned repository and the build file will be saved in you personal Google Drive.

# %%
# %cd /Users/diwaker/Documents/INDIA/productDev/yolo_utils
# Out:
# /Users/diwaker/Documents/INDIA/productDev/yolo_utils

# %%
# !python create_aug_imgDJ.py
# Out:
# v/yolo_utils/final_set_imgaug/train/images/img (6)_jpg.rf.3064aecff151a62fa60bdd7f8ec00ed2_02_1.jpg
# /Users/diwaker/Documents/INDIA/productDev/yolo_utils/final_set_imgaug/train/images/img (6)_jpg.rf.3064aecff151a62fa60bdd7f8ec00ed2_02_2.jpg
# /Users/diwaker/Documents/INDIA/productDev/yolo_utils/final_set_imgaug/train/images/img (6)_jpg.rf.3064aecff151a62fa60bdd7f8ec00ed2_02_3.jpg
# /Users/diwaker/Documents/INDIA/productDev/yolo_utils/final_set_imgaug/train/images/img (6)_jpg.rf.3064aecff151a62fa60bdd7f8ec00ed2_02_4.jpg
# /Users/diwaker/Documents/INDIA/productDev/yolo_utils/final_set_imgaug/train/images/img (6)_jpg.rf.3064aecff151a62fa60bdd7f8ec00ed2_02_5.jpg
# /Users/diwaker/Documents/INDIA/productDev/yolo_utils/final_set_imgaug/train/images/img (6)_jpg.rf.3064aecff151a62fa60bdd7f8ec00ed2_02_6.jpg
# /Users/diwaker/Documents/INDIA/productDev/yolo_utils/final_set_imgaug/train/images/img (6)_jpg.rf.3064aecff151a62fa60bdd7f8ec00ed2_02_7.jpg
# ...

# %%
# !python yolo_info.py -s /Users/diwaker/Documents/INDIA/productDev/yolo_utils/final_set_imgaug/train/images -c classes.txt -f classesFilt.txt
# Out:
# total images: 26840 ; total objects: 44970
#        Class  Nr.Images  Nr.Object     %Image    %Object
# 0  fireSmoke      18300      22600  68.181818  50.255726
# 1     person       8540      22370  31.818182  49.744274

# %%
# !python clean_annotations.py -s /Users/diwaker/Documents/INDIA/productDev/yolo_utils/final_set_imgaug/train/images
# Out:
# 5178ce6863f33556664_02_7.txt
#   Invalid screen coordinates [x1, y1, x2, y2] - (124, 293 259 419)
#     --Adjusted Box successfully
# /Users/diwaker/Documents/INDIA/productDev/yolo_utils/final_set_imgaug/train/images/person_357_jpg.rf.e37bec101b1860e0d7ca6bc0e863ae53_02_8.txt
#   Invalid screen coordinates [x1, y1, x2, y2] - (-4, 132 62 266)
#     --Adjusted Box successfully
# /Users/diwaker/Documents/INDIA/productDev/yolo_utils/final_set_imgaug/train/images/PennPed00001_jpg.rf.0d0d666cc1a2b093d0a8f198e45fceae_02_3.txt
#   Invalid screen coordinates [x1, y1, x2, y2] - (366, 48 434 305)
#     --Adjusted Box successfully
# /Users/diwaker/Documents/INDIA/productDev/yolo_utils/final_set_imgaug/train/images/PennPed00091_jpg.rf.a971b374e3a412738e219886a73385cb_02_0.txt
#   Invalid screen coordinates [x1, y1, x2, y2] - (3, 10 213 448)
#     --Adjusted Box successfully
# ...

# %%
# !python yolo_info.py -s /Users/diwaker/Documents/INDIA/productDev/yolo_utils/final_set_imgaug/train/images -c classes.txt -f classesFilt.txt
# Out:
# total images: 30017 ; total objects: 52841
#        Class  Nr.Images  Nr.Object     %Image    %Object
# 0  fireSmoke      20092      25154  66.935403  47.603187
# 1     person       9925      27687  33.064597  52.396813
